# %% [markdown]
# <h1><u>Pandas Visulization

# %%
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\shaik\OneDrive\Desktop\Courses\Data_Science\Alex_The_Analyst\Pandas\06_Visulization\Resources\IceCreamRatings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="line", subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
df.plot(kind="line", title="Ice-Cream Ratings")
# Out:
# <AxesSubplot:title={'center':'Ice-Cream Ratings'}>

# %%
df.plot(kind="line", title="Ice-Cream Ratings", xlabel="Day", ylabel="Rating")
# Out:
# <AxesSubplot:title={'center':'Ice-Cream Ratings'}, xlabel='Day', ylabel='Rating'>

# %% [markdown]
# <h3 style="color:Green">Bar Graph

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar", stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3 style="color:Red">Scatter Graph

# %%
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Scatter Graph

# %%
df.plot.scatter(x="Texture Rating", y = "Overall Rating", s=500, c="Red")
# Out:
# <AxesSubplot:xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# <h3 style="color:Red">Histogram

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.hist(bins = 1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3 style="color:Red">Box Plot

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3 style="color:Red">Pie Chart

# %%
df.plot.pie(y='Flavor Rating', figsize = (10,5))
# Out:
# <AxesSubplot:ylabel='Flavor Rating'>

# %% [markdown]
# <h3 style="color:Red">Change the style library

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style .use('fivethirtyeight')

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>
